# %%
# !python calc.py
# Out:
# ^C

# %%
# %run calc.py
# Out:
# Calculator Basic
# Moi ban nhap so a:  10
# Moi ban nhap so b:  20
# c = 10 + 20 = 30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
# !jupyter nbconvert --to html main_calc.ipynb
# Out:
# [NbConvertApp] Converting notebook main_calc.ipynb to html
# [NbConvertApp] Writing 274858 bytes to main_calc.html
